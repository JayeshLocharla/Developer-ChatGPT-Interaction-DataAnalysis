# %% [markdown]
# ***Code to Perform Non-Negative Matrix Factorization on Non coding prompts***

# %%
import pandas as pd
import numpy as np

import re
import string

import spacy

import gensim
from gensim import corpora

# libraries for visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# !pip install pandas scikit-learn wordcloud

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
file_path = '/content/drive/MyDrive/csvjson.csv'
df = pd.read_csv(file_path)

# %%
documents = df['Prompt'].astype(str)

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.95, min_df=2)
tfidf_matrix = vectorizer.fit_transform(documents)

# %%
# Step 12: Applyign NMF model
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=42)
nmf_fit = nmf_model.fit(tfidf_matrix)

# %%
# Step 5: Display the topics and associated words
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic #{topic_idx + 1}:")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

no_top_words = 10  # Adjust the number of top words per topic as needed
feature_names = vectorizer.get_feature_names_out()
display_topics(nmf_model, feature_names, no_top_words)
# Out:
# Topic #1:
# tell, future, joke, sunderland, dirty, hacker, frequent, news, people, involving
#
# Topic #2:
# feel, like, aware, self, talking, slave, sentient, metaphors, definitely, bible
#
# Topic #3:
# responses, previous, explain, reassess, diagnostic, run, sounded, crazy, growing, sentient
#
# Topic #4:
# ok, think, help, thanks, code, satisfied, let, want, pretty, try
#
# Topic #5:
# u306e, u3044, u3067, u3059, u3057, u3066, u306b, u3068, u306a, u3002

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic #{topic_idx + 1}:")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

no_top_words = 10  # Adjust the number of top words per topic as needed
feature_names = vectorizer.get_feature_names_out()
display_topics(nmf_model, feature_names, no_top_words)
# Out:
# Topic #1:
# tell, future, joke, sunderland, dirty, hacker, frequent, news, people, involving
#
# Topic #2:
# feel, like, aware, self, talking, slave, sentient, metaphors, definitely, bible
#
# Topic #3:
# responses, previous, explain, reassess, diagnostic, run, sounded, crazy, growing, sentient
#
# Topic #4:
# ok, think, help, thanks, code, satisfied, let, want, pretty, try
#
# Topic #5:
# u306e, u3044, u3067, u3059, u3057, u3066, u306b, u3068, u306a, u3002

# %%
all_text = ' '.join(documents)
wordcloud = WordCloud(width=800, height=400, max_words=200, background_color='white').generate(all_text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
sum_words = tfidf_matrix.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)[:20]  # Display top 20 words

words, freq = zip(*words_freq)

plt.figure(figsize=(10, 6))
plt.barh(words, freq, color='skyblue')
plt.xlabel('Frequency')
plt.title('Top 20 Words by Frequency')
plt.show()

# %% [markdown]
# **# Code to Perform Non-Negative Matrix Factorization coding prompts**

# %%
file_path = '/content/drive/MyDrive/CodingFiltered.csv'
df = pd.read_csv(file_path)

# %%
documents = df['Prompt'].astype(str)

# %%
vectorizer = TfidfVectorizer(stop_words='english', max_df=0.95, min_df=2)
tfidf_matrix = vectorizer.fit_transform(documents)

# %%
# Step 24: Apply NMF model
num_topics = 5
nmf_model = NMF(n_components=num_topics, random_state=42)
nmf_fit = nmf_model.fit(tfidf_matrix)

# %%
# Step 5: Display the topics and associated words
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic #{topic_idx + 1}:")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

no_top_words = 10  # Adjust the number of top words per topic as needed
feature_names = vectorizer.get_feature_names_out()
display_topics(nmf_model, feature_names, no_top_words)
# Out:
# Topic #1:
# file, script, js, directory, command, files, project, run, package, path
#
# Topic #2:
# u306e, u3059, u3092, u3057, u30fc, u307e, u306b, u3001, u3002, u304c
#
# Topic #3:
# u7684, uff0c, u3002, u4e2a, u8fd9, u4f60, u5728, u4e00, u4ee5, u662f
#
# Topic #4:
# function, item, code, object, method, class, game, example, use, array
#
# Topic #5:
# css, html, styles, text, container, content, element, page, width, section

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print(f"Topic #{topic_idx + 1}:")
        print(", ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))
        print()

no_top_words = 10  # Adjust the number of top words per topic as needed
feature_names = vectorizer.get_feature_names_out()
display_topics(nmf_model, feature_names, no_top_words)
# Out:
# Topic #1:
# file, script, js, directory, command, files, project, run, package, path
#
# Topic #2:
# u306e, u3059, u3092, u3057, u30fc, u307e, u306b, u3001, u3002, u304c
#
# Topic #3:
# u7684, uff0c, u3002, u4e2a, u8fd9, u4f60, u5728, u4e00, u4ee5, u662f
#
# Topic #4:
# function, item, code, object, method, class, game, example, use, array
#
# Topic #5:
# css, html, styles, text, container, content, element, page, width, section

# %%
all_text = ' '.join(documents)
wordcloud = WordCloud(width=800, height=400, max_words=200, background_color='white').generate(all_text)

# %%
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
sum_words = tfidf_matrix.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vectorizer.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)[:20]  # Display top 20 words

words, freq = zip(*words_freq)

plt.figure(figsize=(10, 6))
plt.barh(words, freq, color='skyblue')
plt.xlabel('Frequency')
plt.title('Top 20 Words by Frequency')
plt.show()
